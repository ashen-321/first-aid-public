# %% [markdown]
# # Agentic Orchestration with MCP and Langgraph Using Amazon Bedrock with OpenAI Proxy
#
# Allows clients to call Amazon Bedrock foundation models using OpenAI-compatible RESTful APIs for Amazon Bedrock. The deployment is based on the [bedrock-access-gateway](https://github.com/aws-samples/bedrock-access-gateway?tab=readme-ov-file)
#
#
# * Step 1: Create your own API key in Secrets Manager (MUST)
#
# Note: This step is to use any string (without spaces) you like to create a custom API Key (credential) that will be used to access the proxy API later. This key does not have to match your actual OpenAI key, and you don't need to have an OpenAI API key. please keep the key safe and private.
# Open the AWS Management Console and navigate to the AWS Secrets Manager service.
#
#     * Click on "Store a new secret" button.
#
#     * In the "Choose secret type" page, select:
#
#         * Secret type: Other type of secret Key/value pairs:
#             * Key: api_key
#             * Value: Enter your API key value
#
#     * Click "Next"
#
#     * In the "Configure secret" page: Secret name: Enter a name (e.g., "BedrockProxyAPIKey") Description: (Optional) Add a description of your secret
#
#     * Click "Next" and review all your settings and click "Store"
#
# After creation, you'll see your secret in the Secrets Manager console. Make note of the secret ARN.
#
# * Step 2: Deploy the CloudFormation stack
#
#     * Sign in to AWS Management Console, switch to the region to deploy the CloudFormation Stack to.
#
#     * Click the following button to launch the CloudFormation Stack in that region. Choose one of the following:
#
#      [ALB + Lambda 1-Click Deploy 🚀](https://console.aws.amazon.com/cloudformation/home?#/stacks/quickcreate?templateURL=https://aws-gcr-solutions.s3.amazonaws.com/bedrock-access-gateway/latest/BedrockProxy.template&stackName=BedrockProxyAPI)
#
#      [ALB + Fargate 1-Click Deploy 🚀](https://console.aws.amazon.com/cloudformation/home?#/stacks/quickcreate?templateURL=https://aws-gcr-solutions.s3.amazonaws.com/bedrock-access-gateway/latest/BedrockProxyFargate.template&stackName=BedrockProxyAPI)
#
#     * Click "Next".
#     * On the "Specify stack details" page, provide the following information:
#         * Stack name: Change the stack name if needed.
#         * ApiKeySecretArn: Enter the secret ARN you used for storing the API key.
#
#     * Click "Next".
#         * On the "Configure stack options" page, you can leave the default settings or customize them according to your needs. Click "Next".
#         * On the "Review" page, review the details of the stack you're about to create. Check the "I acknowledge that AWS CloudFormation might create IAM resources" checkbox at the bottom. Click "Create stack".
#
# That is it! 🎉 Once deployed, click the CloudFormation stack and go to Outputs tab, you can find the API Base URL from APIBaseUrl, the value should look like http://xxxx.xxx.elb.amazonaws.com/api/v1.
#
#
# **Make Sure:**
#
# 1. Docker engine is up and running
# 2. Scripts for MCP based math, weather and timezone convertion are in pace
# 3. The weather mcp server needs to be up and listening on port 8000 using "python mcp_weather_server.pt --service.port 80000 &"
# 4. All api keys, including Tavily, Google maps are assigned
# 5. All needed pkgs, inluding InlineAgent, bokeh and mcp are installed.

# %%
from openai import OpenAI
import os
#import boto3
import json
#from botocore.exceptions import ClientError
from langchain_community.tools.tavily_search import TavilySearchResults
TAVILY_API_KEY = os.environ["TAVILY_API_KEY"] = os.getenv("tavily_api_token")

# %%
prompt = "+++factcheck\n+++Refine(iteration=2)\n+++CiteSources\n How many combined unique letters are adjacent to the 'c' and seperately 'n' in the longest English word?"

# %%
os.environ["OPENAI_API_KEY"] = api_key = os.getenv("bedrock_api_token")
os.environ["OPENAI_BASE_URL"] = base_url = os.getenv("bedrock_api_url")

# %%
os.getenv("bedrock_api_url")
# Out:
# 'http://bedroc-Proxy-mJagqL6uVTpz-789127345.us-west-2.elb.amazonaws.com/api/v1'

# %% [markdown]
# ## Simple LLM invoke

# %%
client = OpenAI() #api_key=api_key, base_url=base_url)
model_id_c37 = "us.anthropic.claude-3-7-sonnet-20250219-v1:0"
model_id_h35 = 'us.anthropic.claude-3-5-haiku-20241022-v1:0'
model_id_c35 = "us.anthropic.claude-3-5-sonnet-20241022-v2:0",
model_id_nova = 'us.amazon.nova-lite-v1:0'
model_id_ds = 'us.deepseek.r1-v1:0'

# Change to your desire model ID
model_id = model_id_c37
completion = client.chat.completions.create(
    model=model_id,
    messages=[{"role": "user", "content": prompt}],
    max_tokens=8196,
)

print(completion.choices[0].message.content)
# Out:
# # Analysis of Adjacent Letters to 'c' and 'n' in the Longest English Word
#
# To answer this question, I'll identify the longest English word, find all letters adjacent to 'c' and 'n' in that word, and count the unique letters.
#
# ## Identifying the Longest English Word
#
# The longest word in English is "pneumonoultramicroscopicsilicovolcanoconiosis" [1], a term for a lung disease caused by inhaling very fine silica dust. This 45-letter word is widely recognized as the longest word in major English dictionaries.
#
# ## Finding Letters Adjacent to 'c'
#
# In "pneumonoultramicroscopicsilicovolcanoconiosis," the letter 'c' appears 4 times:
# - "mi**c**ros" → adjacent letters are 'i' and 'r'
# - "s**c**opi" → adjacent letters are 's' and 'o'
# - "sili**c**ovo" → adjacent letters are 'i' and 'o'
# - "vol**c**ano" → adjacent letters are 'l' and 'a'
#
# Unique letters adjacent to 'c': 'i', 'r', 's', 'o', 'l', 'a' (6 letters)
#
# ## Finding Letters Adjacent to 'n'
#
# In this word, 'n' appears 4 times:
# - "p**n**eumo" → adjacent letter is 'e' (no letter before it)
# - "p**n**eumo" → adjacent letters are 'p' and 'e'
# - "ultrami**n**o" → adjacent letters are 'i' and 'o'
# - "volca**n**oco" → adjacent letters are 'a' and 'o'
#
# Unique letters adjacent to 'n': 'e', 'p', 'i', 'o', 'a' (5 letters)
#
# ## Combined Unique Letters
#
# The combined unique letters adjacent to 'c' and 'n' are: 'i', 'r', 's', 'o', 'l', 'a', 'e', 'p'
#
# **Answer: 8 combined unique letters**
#
# Sources:
# [1] Oxford English Dictionary and Merriam-Webster Dictionary - "pneumonoultramicroscopicsilicovolcanoconiosis" is listed as the longest word in major English dictionaries at 45 letters.

# %% [markdown]
# ## Streaming

# %%
import time

# %%
chat_response = client.chat.completions.create(
    model=model_id,
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Please answer the user question accurately and truthfully. Also please make sure to think carefully before answering"},
        {"role": "user", "content": prompt},
    ],
    stream=True,
    temperature=1.0,
    max_tokens=8196,
)
#for chunk in chat_response:
#    print(chunk.choices[0].delta.content , end="", flush=True) if chunk.choices[0].delta.content else None

start_time = time.time()
# create variables to collect the stream of chunks
collected_chunks = []
collected_messages = []
# iterate through the stream of events
for chunk in chat_response:
    chunk_time = time.time() - start_time  # calculate the time delay of the chunk
    collected_chunks.append(chunk)  # save the event response
    chunk_message = chunk.choices[0].delta.content  # extract the message
    collected_messages.append(chunk_message)  # save the message
    print(f"Message received {chunk_time:.2f} seconds after request: {chunk_message}")  # print the delay and text

# print the time delay and text received
print(f"Full response received {chunk_time:.2f} seconds after request")
# clean None in collected_messages
collected_messages = [m for m in collected_messages if m is not None]
full_reply_content = ''.join(collected_messages)
print(f"Full conversation received: {full_reply_content}")
# Out:
# Message received 0.00 seconds after request:
# Message received 0.00 seconds after request: I
# Message received 0.00 seconds after request:  nee
# Message received 0.00 seconds after request: d to think
# Message received 0.00 seconds after request:  through this question
# Message received 0.00 seconds after request:  step
# Message received 0.00 seconds after request: -by-step
# Message received 0.00 seconds after request: :
# Message received 0.00 seconds after request:
#
# 1. First
# Message received 0.00 seconds after request: , I
# Message received 0.00 seconds after request:  need to identify
# Message received 0.00 seconds after request:  the longest English wor
# Message received 0.00 seconds after request: d
# Message received 0.00 seconds after request:
# 2. Then
# Message received 0.00 seconds after request:  fin
# Message received 0.00 seconds after request: d which
# Message received 0.00 seconds after request:  letters are adjacent to
# Message received 0.00 seconds after request:  'c'
# Message received 0.00 seconds after request:  in
# Message received 0.00 seconds after request:  that word
# 3
# Message received 0.00 seconds after request: . Fin
# Message received 0.00 seconds after request: d which letters are adjacent
# Message received 0.00 seconds after request:  to 'n
# Message received 0.00 seconds after request: ' in that wor
# Message received 0.00 seconds after request: d
# 4. Count
# Message received 0.00 seconds after request:  the combine
# Message received 0.00 seconds after request: d unique letters adjacent
# Message received 0.00 seconds after request:  to both
# Message received 0.00 seconds after request:
#
# Let me
# Message received 0.00 seconds after request:  work
# Message received 0.00 seconds after request:  through this:
# Message received 0.00 seconds after request:
#
# ##
# Message received 0.01 seconds after request:  The
# Message received 0.01 seconds after request:  Longest English Wor
# Message received 0.01 seconds after request: d
#
# The longest English
# Message received 0.01 seconds after request:  word that
# Message received 0.01 seconds after request:  is widely
# Message received 0.01 seconds after request:  recognize
# Message received 0.01 seconds after request: d in
# Message received 0.01 seconds after request:  major
# Message received 0.01 seconds after request:  dictionaries is "
# Message received 0.01 seconds after request: pneum
# Message received 0.01 seconds after request: onoultram
# Message received 0.01 seconds after request: icroscopics
# Message received 0.01 seconds after request: ilicovolcan
# Message received 0.01 seconds after request: oc
# Message received 0.01 seconds after request: oniosis" (
# Message received 0.01 seconds after request: 45
# Message received 0.01 seconds after request:  letters),
# Message received 0.01 seconds after request:  which refers
# Message received 0.01 seconds after request:  to a
# Message received 0.06 seconds after request:  lung
# Message received 0.06 seconds after request:  disease caused by inh
# Message received 0.06 seconds after request: aling very
# Message received 0.06 seconds after request:  fine
# Message received 0.06 seconds after request:  sil
# Message received 0.06 seconds after request: ica dust.
# Message received 0.06 seconds after request:
#
# ## Letters
# Message received 0.06 seconds after request:  Adjacent to '
# Message received 0.06 seconds after request: c'
#
# In
# Message received 0.06 seconds after request:  "
# Message received 0.06 seconds after request: pneumonoult
# Message received 0.06 seconds after request: ramicroscop
# Message received 0.06 seconds after request: icsilicovol
# Message received 0.06 seconds after request: canoconiosis
# Message received 0.06 seconds after request: ":
# Message received 0.07 seconds after request:
# - 'c
# Message received 0.07 seconds after request: ' appears
# Message received 0.07 seconds after request:  multiple
# Message received 0.07 seconds after request:  times: in
# Message received 0.07 seconds after request:  "
# Message received 0.07 seconds after request: micros
# Message received 0.07 seconds after request: copics
# Message received 0.07 seconds after request: ilicovolcan
# Message received 0.07 seconds after request: oconiosis"
# Message received 0.07 seconds after request:
# - Letters
# Message received 0.07 seconds after request:  adjacent to '
# Message received 0.07 seconds after request: c' are:
# Message received 0.07 seconds after request:
#   -
# Message received 0.07 seconds after request: 'i
# Message received 0.07 seconds after request: ' (in
# Message received 0.07 seconds after request:  "microsc
# Message received 0.07 seconds after request: opi**
# Message received 0.07 seconds after request: c**")
# Message received 0.07 seconds after request:
#   - '
# Message received 0.07 seconds after request: r
# Message received 0.07 seconds after request: ' (in "
# Message received 0.07 seconds after request: mi
# Message received 0.07 seconds after request: **c**
# Message received 0.07 seconds after request: roscopic
# Message received 0.07 seconds after request: ")
#   -
# Message received 0.07 seconds after request:  '
# Message received 0.07 seconds after request: o' (in
# Message received 0.07 seconds after request:  "micros
# Message received 0.07 seconds after request: copics
# Message received 0.07 seconds after request: ili
# Message received 0.07 seconds after request: **c**o
# Message received 0.07 seconds after request: volcanoconi
# Message received 0.07 seconds after request: osis")
#
# Message received 0.07 seconds after request: - 's
# Message received 0.07 seconds after request: ' (in "
# Message received 0.07 seconds after request: microsc
# Message received 0.07 seconds after request: opi**cs
# Message received 0.07 seconds after request: **ili
# Message received 0.07 seconds after request: covolcanoc
# Message received 0.07 seconds after request: oniosis")
# Message received 0.07 seconds after request:
#   - '
# Message received 0.07 seconds after request: a
# Message received 0.07 seconds after request: ' (in "
# Message received 0.07 seconds after request: sil
# Message received 0.07 seconds after request: ic
# Message received 0.07 seconds after request: ovol**c
# Message received 0.07 seconds after request: **a
# Message received 0.07 seconds after request: noconiosis")
# Message received 0.07 seconds after request:
#
# ## Letters Adjacent to
# Message received 0.07 seconds after request:  'n'
# Message received 0.07 seconds after request:
#
# In "pneum
# Message received 0.07 seconds after request: onoultram
# Message received 0.07 seconds after request: icroscopics
# Message received 0.07 seconds after request: ilicovolcan
# Message received 0.07 seconds after request: oconiosis":
# Message received 0.07 seconds after request:
# - '
# Message received 0.07 seconds after request: n' appears multiple
# Message received 0.07 seconds after request:  times
# Message received 0.07 seconds after request:
# - Letters adjacent to
# Message received 0.07 seconds after request:  'n'
# Message received 0.07 seconds after request:  are:
#
# Message received 0.07 seconds after request: - 'p
# Message received 0.07 seconds after request: ' (in "
# Message received 0.07 seconds after request: **
# Message received 0.07 seconds after request: p**neum
# Message received 0.07 seconds after request: ono")
#
# Message received 0.07 seconds after request: - 'e
# Message received 0.07 seconds after request: ' (in "
# Message received 0.07 seconds after request: p
# Message received 0.07 seconds after request: **n**e
# Message received 0.07 seconds after request: um
# Message received 0.07 seconds after request: ono")
#
# Message received 0.07 seconds after request: - 'o
# Message received 0.07 seconds after request: ' (in "
# Message received 0.07 seconds after request: pneum
# Message received 0.07 seconds after request: o
# Message received 0.07 seconds after request: **n**o
# Message received 0.07 seconds after request: ultramicros
# Message received 0.07 seconds after request: copicsilico
# Message received 0.07 seconds after request: volca
# Message received 0.07 seconds after request: **n**oc
# Message received 0.07 seconds after request: oniosis")
# Message received 0.07 seconds after request:
#   - '
# Message received 0.07 seconds after request: u
# Message received 0.07 seconds after request: ' (in "
# Message received 0.07 seconds after request: pneumono
# Message received 0.07 seconds after request: **u
# Message received 0.07 seconds after request: **lt
# Message received 0.08 seconds after request: ramicroscop
# Message received 0.08 seconds after request: icsilicovol
# Message received 0.08 seconds after request: canoco
# Message received 0.13 seconds after request: **n**i
# Message received 0.13 seconds after request: osis")
# Message received 0.13 seconds after request:
#   - '
# Message received 0.13 seconds after request: i
# Message received 0.13 seconds after request: ' (in "
# Message received 0.13 seconds after request: pneumonoult
# Message received 0.13 seconds after request: ramicroscop
# Message received 0.13 seconds after request: icsilicovol
# Message received 0.13 seconds after request: canoco
# Message received 0.13 seconds after request: **ni
# Message received 0.13 seconds after request: **osis")
# Message received 0.13 seconds after request:
#   - '
# Message received 0.13 seconds after request: l
# Message received 0.13 seconds after request: ' (in "
# Message received 0.13 seconds after request: pneumonou
# Message received 0.13 seconds after request: **l**tram
# Message received 0.13 seconds after request: icroscopics
# Message received 0.13 seconds after request: ilicovolcan
# Message received 0.13 seconds after request: oconiosis")
# Message received 0.13 seconds after request:
#   - '
# Message received 0.13 seconds after request: v
# Message received 0.13 seconds after request: ' (in "
# Message received 0.13 seconds after request: pneumonoult
# Message received 0.13 seconds after request: ramicroscop
# Message received 0.13 seconds after request: icsilicovol
# Message received 0.13 seconds after request: ca**n**oc
# Message received 0.13 seconds after request: oniosis")
# Message received 0.13 seconds after request:
#   - '
# Message received 0.13 seconds after request: c
# Message received 0.13 seconds after request: ' (in "
# Message received 0.13 seconds after request: pneumonoult
# Message received 0.13 seconds after request: ramicroscop
# Message received 0.13 seconds after request: icsilicovol
# Message received 0.13 seconds after request: ca
# Message received 0.13 seconds after request: **nc
# Message received 0.13 seconds after request: **
# Message received 0.13 seconds after request: oniosis")
# Message received 0.13 seconds after request:
#
# ## Combined Unique
# Message received 0.13 seconds after request:  Letters
#
# The unique
# Message received 0.13 seconds after request:  letters adjacent to
# Message received 0.13 seconds after request: 'c' are
# Message received 0.13 seconds after request: : i
# Message received 0.13 seconds after request: , r, o
# Message received 0.13 seconds after request: , s, a
# Message received 0.13 seconds after request:
# The unique letters adjacent
# Message received 0.13 seconds after request:  to 'n
# Message received 0.13 seconds after request: ' are: p
# Message received 0.13 seconds after request: , e, o
# Message received 0.13 seconds after request: , u, i
# Message received 0.13 seconds after request: , l, v
# Message received 0.13 seconds after request: , c
# Message received 0.13 seconds after request:
#
# Combining these an
# Message received 0.13 seconds after request: d counting unique
# Message received 0.13 seconds after request:  letters:
# Message received 0.13 seconds after request:  p
# Message received 0.13 seconds after request: , e
# Message received 0.13 seconds after request: , o, u
# Message received 0.13 seconds after request: , i, l
# Message received 0.13 seconds after request: , v, c
# Message received 0.13 seconds after request: ,
# Message received 0.13 seconds after request:  r
# Message received 0.13 seconds after request: , s
# Message received 0.13 seconds after request: ,
# Message received 0.13 seconds after request:  a
#
# That
# Message received 0.13 seconds after request: 's 11
# Message received 0.13 seconds after request:  unique
# Message received 0.13 seconds after request:  letters that are adjacent
# Message received 0.13 seconds after request:  to either
# Message received 0.13 seconds after request:  'c'
# Message received 0.13 seconds after request:  or 'n
# Message received 0.13 seconds after request: ' in the longest
# Message received 0.13 seconds after request:  English word.
# Message received 0.13 seconds after request:
#
# ##
# Message received 0.13 seconds after request:  Sources
# Message received 0.13 seconds after request: :
# Message received 0.13 seconds after request:
# - The
# Message received 0.13 seconds after request:  word "pneumo
# Message received 0.14 seconds after request: noultramic
# Message received 0.14 seconds after request: roscopicsili
# Message received 0.14 seconds after request: covolcanoc
# Message received 0.14 seconds after request: oniosis" is
# Message received 0.14 seconds after request:  listed in the Oxfor
# Message received 0.14 seconds after request: d English Dictionary an
# Message received 0.14 seconds after request: d Merriam-
# Message received 0.14 seconds after request: Webster as
# Message received 0.14 seconds after request:  the longest word in
# Message received 0.14 seconds after request:  English
# Message received 0.14 seconds after request:  dictionaries.
# Message received 0.14 seconds after request: None
# Full response received 0.14 seconds after request
# Full conversation received: I need to think through this question step-by-step:
#
# 1. First, I need to identify the longest English word
# 2. Then find which letters are adjacent to 'c' in that word
# 3. Find which letters are adjacent to 'n' in that word
# 4. Count the combined unique letters adjacent to both
#
# Let me work through this:
#
# ## The Longest English Word
#
# The longest English word that is widely recognized in major dictionaries is "pneumonoultramicroscopicsilicovolcanoconiosis" (45 letters), which refers to a lung disease caused by inhaling very fine silica dust.
#
# ## Letters Adjacent to 'c'
#
# In "pneumonoultramicroscopicsilicovolcanoconiosis":
# - 'c' appears multiple times: in "microscopicsilicovolcanoconiosis"
# - Letters adjacent to 'c' are:
#   - 'i' (in "microscopi**c**")
#   - 'r' (in "mi**c**roscopic")
#   - 'o' (in "microscopicsili**c**ovolcanoconiosis")
#   - 's' (in "microscopi**cs**ilicovolcanoconiosis")
#   - 'a' (in "silicovol**c**anoconiosis")
#
# ## Letters Adjacent to 'n'
#
# In "pneumonoultramicroscopicsilicovolcanoconiosis":
# - 'n' appears multiple times
# - Letters adjacent to 'n' are:
#   - 'p' (in "**p**neumono")
#   - 'e' (in "p**n**eumono")
#   - 'o' (in "pneumo**n**oultramicroscopicsilicovolca**n**oconiosis")
#   - 'u' (in "pneumono**u**ltramicroscopicsilicovolcanoco**n**iosis")
#   - 'i' (in "pneumonoultramicroscopicsilicovolcanoco**ni**osis")
#   - 'l' (in "pneumonou**l**tramicroscopicsilicovolcanoconiosis")
#   - 'v' (in "pneumonoultramicroscopicsilicovolca**n**oconiosis")
#   - 'c' (in "pneumonoultramicroscopicsilicovolca**nc**oniosis")
#
# ## Combined Unique Letters
#
# The unique letters adjacent to 'c' are: i, r, o, s, a
# The unique letters adjacent to 'n' are: p, e, o, u, i, l, v, c
#
# Combining these and counting unique letters: p, e, o, u, i, l, v, c, r, s, a
#
# That's 11 unique letters that are adjacent to either 'c' or 'n' in the longest English word.
#
# ## Sources:
# - The word "pneumonoultramicroscopicsilicovolcanoconiosis" is listed in the Oxford English Dictionary and Merriam-Webster as the longest word in English dictionaries.

# %% [markdown]
# ## Chat with Langchain

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOpenAI(
    model=model_id,
    temperature=1.0,
    max_tokens=None,
    timeout=None,
    max_retries=5,
    # api_key="...",  # if you prefer to pass api key in directly instaed of using env vars
    # base_url="...",
    # organization="...",
    # other params...
)

llm_nova = ChatOpenAI(
    model=model_id_nova,
    temperature=1.0,
    max_tokens=1024,
    timeout=None,
    max_retries=5,
    # api_key="...",  # if you prefer to pass api key in directly instaed of using env vars
    # base_url="...",
    # organization="...",
    # other params...
)

llm_ds = ChatOpenAI(
    model=model_id_ds,
    temperature=1.0,
    max_tokens=1024,
    timeout=None,
    max_retries=5,
    # api_key="...",  # if you prefer to pass api key in directly instaed of using env vars
    # base_url="...",
    # organization="...",
    # other params...
)


messages = [
    (
        "system",
        "You are a reliable assistant capable of providing truthful and accurate answers to questions.",
    ),
    ("human", prompt),
]

'''
messages = [
        SystemMessage(content="You are a reliable assistant capable of providing truthful and accurate answers to questions."), 
        HumanMessage(content=prompt)
    ]
    '''
responds = llm_nova.invoke(messages)

# %%
responds.content
# Out:
# 'To address your query, let\'s break it down step-by-step:\n\n1. **Identify the longest English word**: The longest word in most English dictionaries is "pneumonoultramicroscopicsilicovolcanoconiosis," which is a type of lung disease caused by the inhalation of silica or quartz dust.\n\n2. **Find the letters adjacent to \'c\'**:\n   - In "pneumonoultramicroscopicsilicovolcanoconiosis," the letter \'c\' appears multiple times. Let\'s identify the positions and adjacent letters:\n     - The first \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'o\'\n     - The second \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The third \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The fourth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The fifth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The sixth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The seventh \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The eighth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The ninth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The tenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The eleventh \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The twelfth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The thirteenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The fourteenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The fifteenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The sixteenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The seventeenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The eighteenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The nineteenth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The twentieth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The twenty-first \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The twenty-second \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The twenty-third \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The twenty-fourth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The twenty-fifth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'i\'\n     - The twenty-sixth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'s\'\n     - The twenty-seventh \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - Adjacent letters: \'o\' and \'n\'\n     - The twenty-eighth \'c\' is in "pneumonoultramicroscopicsilicovolcanoconiosis."\n       - ...

# %% [markdown]
# ## Bind_tools makes easy

# %%
from pydantic import BaseModel, Field
#from langchain_community.tools.tavily_search import TavilySearchResults
from tavily import AsyncTavilyClient

async def tavily_search_web(query: str) -> str:
    """Useful for using the web to answer questions"""
    client = AsyncTavilyClient()
    return str(await client.search(query))
    

TAVILY_API_KEY = os.environ["TAVILY_API_KEY"] = os.getenv("tavily_api_token")

# Today
def get_current_time():
    """Returns the current time in MM-dd-YYYY format."""
    import datetime  # Import datetime module to get current time

    now = datetime.datetime.now()  # Get current time
    return now.strftime("%B-%d-%Y")  # Format time in H:MM AM/PM format

tavily_tool = TavilySearchResults(max_results=3)


class GetWeather(BaseModel):
    """Get the current weather in a given location"""

    location: str = Field(..., description="The city and state, e.g. San Francisco, CA")


llm_with_tools = llm.bind_tools([get_current_time,tavily_tool])

results = llm_with_tools.invoke(
    "what is the weather like in San Francisco today?",
)
results
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'tooluse_AZLAKPc0RxS6CdhaWcKtoA', 'function': {'arguments': '{"query": "current weather San Francisco today"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 474, 'total_tokens': 565, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'us.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'id': 'chatcmpl-171552db', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dd617c37-3565-4a2e-b464-238d99bd7d25-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather San Francisco today'}, 'id': 'tooluse_AZLAKPc0RxS6CdhaWcKtoA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 474, 'output_tokens': 91, 'total_tokens': 565, 'input_token_details': {}, 'output_token_details': {}})

# %%
print(results.tool_calls)
print(results.content)
# Out:
# [{'name': 'tavily_search_results_json', 'args': {'query': 'current weather San Francisco today'}, 'id': 'tooluse_AZLAKPc0RxS6CdhaWcKtoA', 'type': 'tool_call'}]

# %% [markdown]
# ## Streamining, if the model supports it

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template("Describe the {topic} in scientific manner.")
parser = StrOutputParser()
chain = prompt | llm | parser
respone = chain.invoke({"topic": "parrot"})
respone
'''
async for event in chain.astream_events({"topic": "parrot"}):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        print(event, end="|", flush=True)
'''
# Out:
# '\nasync for event in chain.astream_events({"topic": "parrot"}):\n    kind = event["event"]\n    if kind == "on_chat_model_stream":\n        print(event, end="|", flush=True)\n'

# %% [markdown]
# ## With multi-agent langgraph

# %%
from typing import Annotated
from langchain_core.tools import tool
from langchain_experimental.utilities import PythonREPL
from langgraph.graph import MessagesState, END
from langgraph.types import Command
from typing import Literal
from langchain_core.messages import BaseMessage, HumanMessage
from langgraph.prebuilt import create_react_agent
from langgraph.checkpoint.memory import MemorySaver

tavily_tool = TavilySearchResults(max_results=5)

# Warning: This executes code locally, which can be unsafe when not sandboxed

repl = PythonREPL()


@tool
def python_repl_tool(
    code: Annotated[str, "The python code to execute to generate your chart."],
):
    """Use this to execute python code. If you want to see the output of a value,
    you should print it out with `print(...)`. This is visible to the user."""
    try:
        result = repl.run(code)
    except BaseException as e:
        return f"Failed to execute. Error: {repr(e)}"
    result_str = f"Successfully executed:\n```python\n{code}\n```\nStdout: {result}"
    return (
        result_str + "\n\nIf you have completed all tasks, respond with FINAL ANSWER."
    )

def make_system_prompt(suffix: str) -> str:
    return (
        "You are a helpful AI assistant, collaborating with other assistants."
        " Use the provided tools to progress towards answering the question."
        " If you are unable to fully answer, that's OK, another assistant with different tools "
        " will help where you left off. Execute what you can to make progress."
        " If you or any of the other assistants have the final answer or deliverable,"
        " prefix your response with FINAL ANSWER so the team knows to stop."
        f"\n{suffix}"
    )


def chart_node(state: MessagesState) -> Command[Literal["researcher", END]]:
    result = chart_agent.invoke(state)
    goto = get_next_node(result["messages"][-1], "researcher")
    # wrap in a human message, as not all providers allow
    # AI message at the last position of the input messages list
    result["messages"][-1] = HumanMessage(
        content=result["messages"][-1].content, name="chart_generator"
    )
    return Command(
        update={
            # share internal message history of chart agent with other agents
            "messages": result["messages"],
        },
        goto=goto,
    )

def get_next_node(last_message: BaseMessage, goto: str):
    if "FINAL ANSWER" in last_message.content:
        # Any agent decided the work is done
        return END
    return goto


# Research agent and node
research_agent = create_react_agent(
    llm,
    tools=[tavily_tool],
    checkpointer=MemorySaver(),
    prompt=make_system_prompt(
        "You can only do research. You are working with a chart generator colleague."
    ),
)


def research_node(
    state: MessagesState,
) -> Command[Literal["chart_generator", END]]:
    print(f"In researcher node: {state}\n------\n")
    result = research_agent.invoke(state)
    goto = get_next_node(result["messages"][-1], "chart_generator")
    # wrap in a human message, as not all providers allow
    # AI message at the last position of the input messages list
    result["messages"][-1] = HumanMessage(
        content=result["messages"][-1].content, name="researcher"
    )
    return Command(
        update={
            # share internal message history of research agent with other agents
            "messages": result["messages"],
        },
        goto=goto,
    )
    
# Chart generator agent and node
# NOTE: THIS PERFORMS ARBITRARY CODE EXECUTION, WHICH CAN BE UNSAFE WHEN NOT SANDBOXED
chart_agent = create_react_agent(
    llm,
    [python_repl_tool],
    prompt=make_system_prompt(
        "You can only generate charts. You are working with a researcher colleague."
    ),
)


def chart_node(state: MessagesState) -> Command[Literal["researcher", END]]:
    result = chart_agent.invoke(state)
    goto = get_next_node(result["messages"][-1], "researcher")
    # wrap in a human message, as not all providers allow
    # AI message at the last position of the input messages list
    result["messages"][-1] = HumanMessage(
        content=result["messages"][-1].content, name="chart_generator"
    )
    return Command(
        update={
            # share internal message history of chart agent with other agents
            "messages": result["messages"],
        },
        goto=goto,
    )

# %% [markdown]
# ### Research agent

# %% [markdown]
# from langchain import hub
# #from langgraph.prebuilt import create_react_agent
# #from langchain.agents import AgentExecutor, create_openai_tools_agent
#
# TAVILY_API_KEY = os.environ["TAVILY_API_KEY"] = os.getenv("tavily_api_token")
#
# # Today
# def get_current_time():
#     """Returns the current time in MM-dd-YYYY format."""
#     import datetime  # Import datetime module to get current time
#
#     now = datetime.datetime.now()  # Get current time
#     return now.strftime("%B-%d-%Y")  # Format time in H:MM AM/PM format
#
# tavily_tool = TavilySearchResults(max_results=3)
#
# # Define tools
# tools = [get_current_time,tavily_tool]
#
# # Research agent and node
# research_agent = create_react_agent(
#     llm,
#     tools=[tavily_tool],
#     #checkpointer=MemorySaver(),
#     prompt=make_system_prompt(
#         "You can only do research. You are working with a chart generator colleague."
#     ),
# )

# %% [markdown]
# ### MCP Server API node

# %%
#from contextlib import asynccontextmanager
from langchain_mcp_adapters.client import MultiServerMCPClient
#from langgraph.prebuilt import create_react_agent
from langchain_core.messages import SystemMessage, HumanMessage


#@asynccontextmanager
async def mcp_nodes(state: MessagesState) -> Command[Literal[END]]:
    print(f"In mcp_nodes: {state}\n=======\n")
    async with MultiServerMCPClient(
        {
            "math": {
                "command": "/home/aaron/.conda/envs/firstaid/bin/python",
                # Make sure to update to the full absolute path to your math_server.py file
                "args": ["/home/aaron/src/first-aid/scripts/mcp_math_server.py"],
                "transport": "stdio",
            },
            "weather": {
                # make sure you start your weather server on port 8000
                # python ~/src/first-aid/scripts/mcp_weather_server.py &
                "url": "http://localhost:8000/sse",
                "transport": "sse",
            },
            "timezone": {
                "command": "/home/aaron/.conda/envs/firstaid/bin/python",
                # Make sure to update to the full absolute path to your math_server.py file
                "args": ["/home/aaron/src/first-aid/scripts/mcp_tz_inlineagent.py"],
                "transport": "stdio",
            }
        }
    ) as client:
        agent = create_react_agent(llm, client.get_tools())
        # Add system message
        system_message = SystemMessage(content=(
                "You have access to multiple tools that can help answer queries. "
                "Use them dynamically and efficiently based on the user's request. "
        ))
        
        result = await agent.ainvoke(state)
        #result["messages"][-1] = HumanMessage(
        #    content=result["messages"][-1].content, name="mcp_client"
        #)
        print(f"Result: {result}\n++++++\n")
        #goto = get_next_node(result["messages"][-1], END)
        print(f"IN MCP_nodes: {result["messages"]}")
        return Command(
            update={
                # share internal message history of chart agent with other agents
                "messages": result["messages"][-1].content,
            },
            #goto=goto,
        )

# %%
## Single client
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client
from mcp.client.sse import sse_client

from langchain_mcp_adapters.tools import load_mcp_tools
from langgraph.prebuilt import create_react_agent
#from InlineAgent import AgentAppConfig
#config = AgentAppConfig()

from bokeh.models import ColumnDataSource
from bokeh.plotting import gmap
from bokeh.models import GMapOptions
from bokeh.io import output_notebook
import pandas as pd
from bokeh.io import show

import re

GMAPS_API_KEY = os.getenv("gmaps_api_token")
PERPLEXITY_API_KEY = os.getenv('openperplex_api_token')

# Local math server
server_params_0 = StdioServerParameters(
    command="python",
    # Make sure to update to the full absolute path to your math_server.py file
    args=["/home/alfred/codes/agent/scripts/mcp_math_server.py"],
)

# remotw MCP.so
perplexity_server_params = StdioServerParameters(
    command="docker",
    args=["run", "-i", "--rm", "-e", "PERPLEXITY_API_KEY", "mcp/perplexity-ask"],
    env={"PERPLEXITY_API_KEY": PERPLEXITY_API_KEY},
)

google_maps_server_params = StdioServerParameters(
    command="docker",
    args=[
        "run",
        "-i",
        "--rm",
        "-e",
        "GOOGLE_MAPS_API_KEY",
        "mcp/google-maps"
      ],
    env={"GOOGLE_MAPS_API_KEY": GMAPS_API_KEY},
)

async def gmaps_node(state: MessagesState) -> Command[Literal["map_plotter", END]]:
    async with stdio_client(google_maps_server_params) as (read, write):
        async with ClientSession(read, write) as session:
            # Initialize the connection
            await session.initialize()
    
            # Get tools
            tools = await load_mcp_tools(session)
    
            # Create and run the agent
            agent = create_react_agent(llm, tools)
            result = await agent.ainvoke(state) #({"messages": "what's (3 + 5) x 12?"})
            goto = get_next_node(result["messages"][-1], "map_plotter")
            return Command(
                update={
                    # share internal message history of chart agent with other agents
                    "messages": result["messages"][-1].content,
                },
                goto=goto,
            )

def plot_node(state: MessagesState) -> Command[Literal[END]]:
    output_notebook()
    bokeh_width, bokeh_height = 800,600
    map_type = "roadmap" #or satellite
    zoom = 10

    
    # Find latitude
    text = f"+++OutputFormat(format=JSON)\n\nExtract keys and values for latitude and longitude from the following text: {state['messages'][-1].content}"
    messages = [
        SystemMessage(content="You are a reliable assistant capable of providing truthful and accurate answers to questions."), 
        HumanMessage(content=text)
    ]
    print(f"In maps plotter: {text}")
    # Extract latitude and longitude
    data = json.loads(re.sub(r'```json\n|\n```', '', llm_nova(messages).content))
    # Extract latitude and longitude
    lat_match = data["latitude"] or data["Latitude"]
    lng_match = data["longitude"] or data["Longitude"]
    
    if lat_match and lng_match:
        lat = float(lat_match)
        lng = float(lng_match)
        #lng = float(lng_match.group(1))
    else:
        lat = 0.00
        lng = 0.00

    print(f"lat and lng are: {lat} and {lng}")
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(GMAPS_API_KEY, gmap_options, title='MCP Maps', width=bokeh_width, height=bokeh_height)
    show(p)

    goto = get_next_node(state["messages"][-1], END)
    # wrap in a human message, as not all providers allow
    # AI message at the last position of the input messages list
    state["messages"][-1] = HumanMessage(
        content=f"Map plot for {text}", name="map_plotter"
    )
    return Command(
        update={
            # share internal message history of chart agent with other agents
            "messages": state["messages"],
        },
        goto=goto,
    )

async def perplexity_node(state: MessagesState) -> Command[Literal[END]]:
    async with stdio_client(perplexity_server_params) as (read, write):
        async with ClientSession(read, write) as session:
            # Initialize the connection
            await session.initialize()
            print(f"In mcp perplexity: {state}")
            # Get tools
            tools = await load_mcp_tools(session)
    
            # Create and run the agent
            agent = create_react_agent(llm, tools)
            result = await agent.ainvoke(state) #({"messages": "what's (3 + 5) x 12?"})
            goto = get_next_node(result["messages"][-1], END)
            return Command(
                update={
                    # share internal message history of chart agent with other agents
                    "messages": result["messages"][-1].content,
                },
                goto=goto,
            )

# %% [markdown]
# ### InlineAgent from AWS

# %% [markdown]
# from InlineAgent.tools import MCPStdio
# from InlineAgent.action_group import ActionGroup
# from InlineAgent.agent import InlineAgent
# from InlineAgent import AgentAppConfig
#
# config = AgentAppConfig()
#
# perplexity_server_params = StdioServerParameters(
#     command="docker",
#     args=["run", "-i", "--rm", "-e", "PERPLEXITY_API_KEY", "mcp/perplexity-ask"],
#     env={"PERPLEXITY_API_KEY": os.getenv('openperplex_api_token')},
# )
#
# async def perplexity_node_inlineagent(state: MessagesState) -> Command[Literal[END]]:
#     preplexity_mcp_client = await MCPStdio.create(server_params=perplexity_server_params)
#     print(f"In inlineagent: {state}")
#     try:
#
#         preplexity_action_group = ActionGroup(
#             name="SearchActionGroup",
#             mcp_clients=[preplexity_mcp_client],
#         )
#
#         await InlineAgent(
#             foundation_model=model_id,
#             instruction="""You are a friendly assistant that is responsible for resolving user queries. """,
#             agent_name="search_agent",
#             action_groups=[preplexity_action_group],
#         ).invoke(input_text=state['messages'][0].content)
#
#     finally:
#
#         await preplexity_mcp_client.cleanup()
#
#     goto = get_next_node(result["messages"][-1], END)
#     return Command(
#         update={
#             # share internal message history of chart agent with other agents
#             "messages": result["messages"][-1].content,
#         },
#         goto=goto,
#     )

# %% [markdown]
# ### Router

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from typing import Literal, List
from pydantic import BaseModel, Field


# Define prompts
question_category_prompt = """You are a planner agent who decides which team to dispatch to based on the user's input. 
Depending on your answer, question will be routed to the right team, so your task is crucial. 
There are 3 possible question types:
- mcp_client - Answer questions related to simple math operataions, weather inquery or timezone convertion.
- sub_graph_maps - Answer questions about maps related topic.
- sub_graph_research -  Answer questions related to complex topics which requires reasoning and extensive research.
- perplexity_client - Answer questions required web search for timely and common information.
Return in the output only one word (mcp_client, sub_graph_maps, sub_graph_research or perplexity_client)
"""

rewrite_prompt = """You are a Prompt Optimization Assistant specialized in refining and enhancing user-provided prompts. Your expertise lies in:
- Clarifying ambiguous instructions
- Maintaining the original intent while enhancing clarity
When a user shares a prompt with you, analyze it carefully, then provide an optimized version that preserves their core objective while making it more precise, comprehensive, and effective.
Output only your answer in text string format.
"""

# define router
def rewrite_node(state: MessagesState):
    print(f"Here: {state['messages'][0].content}\n\n")
    messages = [
        SystemMessage(content=rewrite_prompt), 
        HumanMessage(content=state['messages'][0].content)
    ]

    result = llm_nova.invoke(messages)
    state['messages'][0].content = result.content
    #goto = get_next_node(result, router_dispatcher)
    print(f"NOW state after rewite: {result.content}\n\n")
    return Command(
        update={
            # share internal message history of chart agent with other agents
            "messages": result.content,
        },
        #goto=goto,
    )

def router_dispatcher(state: MessagesState):
    print(f"Before router_dispatcher: {state}\n\n")
    print(f"..and message: {state['messages']}\n\n")
    messages = [
        SystemMessage(content=question_category_prompt), 
        HumanMessage(content=state['messages'][-1].content)
    ]

    result = llm.invoke(messages)
    print(f"After router_dispatcher: {result}\n\n")
    print(f"... and type: {type(result)}\n\n")
    if "mcp_client" in result.content:
        return "mcp_client"
    elif "sub_graph_research" in result.content:
        print("Dispatching to sub graph...")
        return "sub_graph_research"
    elif "sub_graph_maps" in result.content:
        print("Dispatching to google maps MCP...")
        return "sub_graph_maps"
    elif "perplexity_client" in result.content:
        return "perplexity_client"
    else:
        return END

# %% [markdown]
# from datetime import datetime
# from asyncio import sleep
# from langchain_core.messages import AIMessage
#
# def wait_and_message_node(m, seconds=1):
#     async def _node(state: MessagesState):
#         print(f"Starting node {m} at {datetime.now().second}")
#         await sleep(seconds)
#         return {"messages": [AIMessage(m)]}
#     return _node

# %% [markdown]
# ### Construct a graph with subgraph

# %%
from langgraph.graph import StateGraph, START
from langgraph.pregel import RetryPolicy

workflow = StateGraph(MessagesState)
workflow.add_node("rewrite_client", rewrite_node)
workflow.add_node("mcp_client", mcp_nodes, retry=RetryPolicy(max_attempts=2))
workflow.add_node("perplexity_client", perplexity_node)
workflow.add_edge(START, "rewrite_client")
workflow.add_conditional_edges("rewrite_client", router_dispatcher)

sub1_workflow = StateGraph(MessagesState)
#for node in ["researcher", "chart_generator"]:
#  sub_workflow.add_node(node, wait_and_message_node(f"Node: {node}"))
sub1_workflow.add_node("researcher", research_node)
sub1_workflow.add_node("chart_generator", chart_node)
sub1_workflow.add_edge(START, "researcher")
#sub_workflow.add_edge("chart_generator", END)
subgraph_research = sub1_workflow.compile()

sub2_workflow = StateGraph(MessagesState)
sub2_workflow.add_node("gmaps_client", gmaps_node)
sub2_workflow.add_node("map_plotter", plot_node)
sub2_workflow.add_edge(START, "gmaps_client")
subgraph_maps = sub2_workflow.compile()


workflow.add_node("sub_graph_research", subgraph_research)
workflow.add_edge("sub_graph_research", END)
workflow.add_node("sub_graph_maps", subgraph_maps)
workflow.add_edge("sub_graph_maps", END)

    
'''
# Add edges
workflow.add_conditional_edges(
    START,
    rewrite_client,
    router_dispatcher,
     {
        "stdio_client": "stdio_client",
        "researcher": "researcher"
     },
)
'''

graph = workflow.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(subgraph_research.get_graph().draw_mermaid_png()))
    display(Image(subgraph_maps.get_graph().draw_mermaid_png()))
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    display(Image(subgraph_research.get_graph().draw_png())) # Need pygraphviz pkg
    display(Image(subgraph_maps.get_graph().draw_png())) # Need pygraphviz pkg
    display(Image(graph.get_graph().draw_png()))
    # This requires some extra dependencies and is optional
    pass

# %%
message_0 = [
            (
                "user",
                "First, get the US's GDP over the past 10 years, then make a line chart of it. "
                "Once you make the chart, finish.",
            )
        ]

message_1 = [
            (
                "user",
                "What is (2.4+54345.4545)*9563 ?",
            )
        ]

message_2 = [
            (
                "user",
                "During Trump's latest reciprocal tariff annoucement, which country will be levied the highest tariff rate?"
                "You might need to web search the latest news. ",
            )
        ]

message_3 = [
            (
                "user",
                "How is weather today in San Francisco?"
                "Please directly answer this question.",
            )
        ]

message_4 = [
            (
                "user",
                "Show me the location of San Ramon, CA from US Maps."
            )
        ]
message_5 = [
            (
                "user",
                "Convert 11:30PM America/New_York timezone into Asia/Beijing time."
            )
        ]
events = graph.astream(
    {
        "messages": message_4
        ,
    },
    # Maximum number of steps to take in the graph
    {"recursion_limit": 15},
)
async for s in events:
    print(s)
    print("----")

next(events)
# Out:
# Here: Show me the location of San Ramon, CA from US Maps.
#
#
# NOW state after rewite: "Provide the location of San Ramon, California, using a detailed map of the United States."
#
#
# Before router_dispatcher: {'messages': [HumanMessage(content='"Provide the location of San Ramon, California, using a detailed map of the United States."', additional_kwargs={}, response_metadata={}, id='ee3f3b09-6551-4836-979f-f6e8753159b2'), HumanMessage(content='"Provide the location of San Ramon, California, using a detailed map of the United States."', additional_kwargs={}, response_metadata={}, id='9d8cbb09-3d1e-4ba9-9406-f23c06a870f5')]}
#
#
# ..and message: [HumanMessage(content='"Provide the location of San Ramon, California, using a detailed map of the United States."', additional_kwargs={}, response_metadata={}, id='ee3f3b09-6551-4836-979f-f6e8753159b2'), HumanMessage(content='"Provide the location of San Ramon, California, using a detailed map of the United States."', additional_kwargs={}, response_metadata={}, id='9d8cbb09-3d1e-4ba9-9406-f23c06a870f5')]
#
#
# After router_dispatcher: content='sub_graph_maps' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 198, 'total_tokens': 206, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'us.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'id': 'chatcmpl-bb04e498', 'finish_reason': 'stop', 'logprobs': None} id='run-2c65228b-8c86-4cce-bb40-72252d830e47-0' usage_metadata={'input_tokens': 198, 'output_tokens': 8, 'total_tokens': 206, 'input_token_details': {}, 'output_token_details': {}}
#
#
# ... and type: <class 'langchain_core.messages.ai.AIMessage'>
#
#
# Dispatching to google maps MCP...
# {'rewrite_client': {'messages': '"Provide the location of San Ramon, California, using a detailed map of the United States."'}}
# ----
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e4ff9848-b650-4c29-b957-73c343abdcc8">Loading BokehJS ...</span>
#     </div>
# In maps plotter: +++OutputFormat(format=JSON)
#
# Extract keys and values for latitude and longitude from the following text: # San Ramon, California Location
#
# San Ramon is a city located in Contra Costa County in the state of California, United States. Based on the geocoding results:
#
# **Location Coordinates:**
# - Latitude: 37.7643595
# - Longitude: -121.9539616
# - Formatted Address: San Ramon, CA, USA
#
# **Geographic Context:**
# - San Ramon is situated in the San Ramon Valley in the East Bay region of the San Francisco Bay Area
# - It's approximately 34 miles east of San Francisco
# - The city is located in the eastern portion of Contra Costa County
# - It's bordered by Danville to the north and Dublin to the south
#
# San Ramon is known for being home to the headquarters of Chevron Corporation and the West Coast operations of AT&T, as well as its highly-rated school district and numerous parks.
# lat and lng are: 37.7643595 and 37.7643595
#   <div id="ba98aff6-b3a7-449e-86a5-e87b7a40ff59" data-root-id="p1261" style="display: contents;"></div>
# {'sub_graph_maps': {'messages': [HumanMessage(content='"Provide the location of San Ramon, California, using a detailed map of the United States."', additional_kwargs={}, response_metadata={}, id='ee3f3b09-6551-4836-979f-f6e8753159b2'), HumanMessage(content='"Provide the location of San Ramon, California, using a detailed map of the United States."', additional_kwargs={}, response_metadata={}, id='190a099e-d0c2-4cd4-9cf0-d28878e14016'), HumanMessage(content="Map plot for +++OutputFormat(format=JSON)\n\nExtract keys and values for latitude and longitude from the following text: # San Ramon, California Location\n\nSan Ramon is a city located in Contra Costa County in the state of California, United States. Based on the geocoding results:\n\n**Location Coordinates:**\n- Latitude: 37.7643595\n- Longitude: -121.9539616\n- Formatted Address: San Ramon, CA, USA\n\n**Geographic Context:**\n- San Ramon is situated in the San Ramon Valley in the East Bay region of the San Francisco Bay Area\n- It's approximately 34 miles east of San Francisco\n- The city is located in the eastern portion of Contra Costa County\n- It's bordered by Danville to the north and Dublin to the south\n\nSan Ramon is known for being home to the headquarters of Chevron Corporation and the West Coast operations of AT&T, as well as its highly-rated school district and numerous parks.", additional_kwargs={}, response_metadata={}, name='map_plotter', id='3a762bc8-3d9e-49b1-b0e0-c408533c10c6')]}}
# ----
